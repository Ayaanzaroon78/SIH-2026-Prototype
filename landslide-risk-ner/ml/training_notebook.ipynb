# %% [markdown]
# # SIH26001: AI-Based Landslide Risk Monitoring System (NER)
# ## ML Model Development, Evaluation & Explainability Notebook
#
# This notebook demonstrates dataset generation, feature engineering, model training using XGBoost, evaluation metrics (RMSE, MAE, R², Accuracy, F1-Score), and feature importance analysis for landslide risk scoring across North Eastern Region (NER) locations.

# %%
import os
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from data_generator import generate_synthetic_data
from train_model import train_and_evaluate_model

# 1. Generate / Load Synthetic Dataset
df = generate_synthetic_data()
df.head()

# %% [markdown]
# ### Exploratory Data Analysis & Feature Distribution

# %%
df.describe()

# %% [markdown]
# ### Train Model and Extract Performance Metrics

# %%
metadata = train_and_evaluate_model()
print(json.dumps(metadata, indent=2))

# %% [markdown]
# ### Feature Importance Explanation

# %%
importances = metadata['feature_importances']
features = list(importances.keys())
values = [v * 100 for v in importances.values()]

plt.figure(figsize=(10, 5))
plt.barh(features, values, color='#ea580c')
plt.xlabel('Importance (%)')
plt.title('Landslide Risk Prediction Feature Importance (SIH26001)')
plt.gca().invert_yaxis()
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
